# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,5,11)
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y = x**2

# %%
plt.plot(x,y)
plt.title("test plot")
plt.xlabel("Rand x Values")
plt.ylabel("Rand y value")
# Out:
# Text(0, 0.5, 'Rand y value')
